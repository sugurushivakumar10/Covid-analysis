# %%
import pandas as pd

# %%
covid = pd.read_json("https://www.mohfw.gov.in/data/datanew.json")

# %%
covid
# Out:
#       sno                                state_name  active  positive  \
# 0       2               Andaman and Nicobar Islands     199      4036
# 1       1                            Andhra Pradesh   42855    763573
# 2       3                         Arunachal Pradesh    2960     12561
# 3       4                                     Assam   28897    196786
# 4       5                                     Bihar   10835    198855
# 5       6                                Chandigarh    1127     13331
# 6       7                              Chhattisgarh   27208    147866
# 7       8  Dadra and Nagar Haveli and Daman and Diu      85      3168
# 8      10                                     Delhi   21490    314224
# 9      11                                       Goa    4316     39082
# 10     12                                   Gujarat   15187    153761
# 11     13                                   Haryana   10319    144302
# 12     14                          Himachal Pradesh    2507     17762
# 13     15                         Jammu and Kashmir    9866     84708
# 14     16                                 Jharkhand    7617     93736
# 15     17                                 Karnataka  113478    726106
# 16     18                                    Kerala   95493    303896
# 17     19                                    Ladakh     969      5238
# 18     20                               Lakshadweep       0         0
# 19     21                            Madhya Pradesh   14661    149761
# 20     22                               Maharashtra  205884   1543837
# 21     23                                   Manipur    2867     13793
# 22     24                                 Meghalaya    2367      7838
# 23     25                                   Mizoram     119      2212
# 24     26                                  Nagaland    1513      7363
# 25     27                                    Odisha   22892    256937
# 26     28                                Puducherry    4572     32004
# 27     29                                    Punjab    8212    125211
# 28     30                                 Rajasthan   21924    163219
# 29     31                                    Sikkim     344      3417
# 30     32                                Tamil Nadu   43239    665930
# 31     34                                 Telengana   23728    216238
# 32     33                                   Tripura    3500     28859
# 33     35                               Uttarakhand    6576     55641
# 34     36                             Uttar Pradesh   38082    442118
# 35     37                               West Bengal   30988    302020
# 36  11111                                            826876   7239389
#
#       cured   death  new_active  new_positive  new_cured  new_death state_code
# 0      3782      55         195          4046       3796         55         35
# 1    714427    6291       41669        767465     719477       6319         28
# 2      9573      28        3045         12768       9694         29         12
# 3    167059     830       29307        198213     168072        834         18
# 4    187059     961       10756        200103     188380        967         10
# 5     12007     197        1085         13403      12119        199         04
# 6    119352    1306       27809        150696     121548       1339         22
# 7      3081       2          79          3171       3090          2         26
# 8    286880    5854       21903        317548     289747       5898         07
# 9     34252     514        4188         39438      34731        519         30
# 10   134990    3584       14937        154936     136404       3595         24
# 11   132382    1601       10187        145507     133706       1614         06
# 12    15001     254        2520         18008      15233        255         02
# 13    73502    1340        9739         85409      74318       1352         01
# 14    85314     805        7191         94369      86367        811         20
# 15   602505   10123      114006        735371     611167      10198         29
# 16   207357    1046       93925        310140     215149       1066         32
# 17     4205      64         979          5304       4261         64         37
# 18        0       0           0             0          0          0         31
# 19   132429    2671       14432        155276     138158       2686         23
# 20  1297252   40701      196761       1554389    1316769      40859         27
# 21    10829      97        3076         14094      10915        103         14
# 22     5406      65        2339          7991       5582         70         17
# 23     2093       0         112          2220       2108          0         15
# 24     5831      19        1478          7416       5916         22         13
# 25   232988    1057       22716        259541     235763       1062         21
# 26    26865     567        4525         32245      27152        568         34
# 27   113105    3894        7760        125760     114075       3925         03
# 28   139616    1679       21711        165240     141835       1694         08
# 29     3014      59         325          3459       3075         59         11
# 30   612320   10371       42566        670392     617403      10423         33
# 31   191269    1241       23203        217670     193218       1249         36
# 32    25041     318        3318         29031      25394        319         16
# 33    48283     782        6145         56070      49129        796         05
# 34   397570    6466       36898        444711     401306       6507         09
# 35   265288    5744       31505        305697     268384       5808         19
# 36  6301927  110586      812390       7307097    6383441     111266

# %%
covid = covid.iloc[:-1,1:]

# %%
covid.head()
# Out:
#                     state_name  active  positive   cured  death  new_active  \
# 0  Andaman and Nicobar Islands     199      4036    3782     55         195
# 1               Andhra Pradesh   42855    763573  714427   6291       41669
# 2            Arunachal Pradesh    2960     12561    9573     28        3045
# 3                        Assam   28897    196786  167059    830       29307
# 4                        Bihar   10835    198855  187059    961       10756
#
#    new_positive  new_cured  new_death state_code
# 0          4046       3796         55         35
# 1        767465     719477       6319         28
# 2         12768       9694         29         12
# 3        198213     168072        834         18
# 4        200103     188380        967         10

# %%
covid.tail()
# Out:
#        state_name  active  positive   cured  death  new_active  new_positive  \
# 31      Telengana   23728    216238  191269   1241       23203        217670
# 32        Tripura    3500     28859   25041    318        3318         29031
# 33    Uttarakhand    6576     55641   48283    782        6145         56070
# 34  Uttar Pradesh   38082    442118  397570   6466       36898        444711
# 35    West Bengal   30988    302020  265288   5744       31505        305697
#
#     new_cured  new_death state_code
# 31     193218       1249         36
# 32      25394        319         16
# 33      49129        796         05
# 34     401306       6507         09
# 35     268384       5808         19

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\asadkhan\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#conda install matplotlib --force

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18,18))
sns.barplot(x="state_name",y="active",data=covid)
plt.show()

# %% [markdown]
# ## Active cases in India

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x="state_name", y="active", data=covid, palette=sns.color_palette("GnBu", 10))
plt.xticks(rotation='vertical')
ax.grid(b=True, which='major', color='#d3d3d3', linewidth=1.0)
ax.grid(b=True, which='minor', color='#d3d3d3', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Positive cases in India

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x="state_name", y="positive", data=covid, palette=sns.color_palette("GnBu", 10))
plt.xticks(rotation='vertical')
ax.grid(b=True, which='major', color='#d3d3d3', linewidth=1.0)
ax.grid(b=True, which='minor', color='#d3d3d3', linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(18,18))
plt.xticks(rotation='vertical')
sns.barplot(data=covid,x="state_name", y="death")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x="positive",y="death",data=covid)

# %%
#! pip install sweetviz

# %%
covid.columns
# Out:
# Index(['state_name', 'active', 'positive', 'cured', 'death', 'new_active',
#        'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x="state_name",y="active",data =covid)
plt.xticks(rotation='vertical')
sns.lineplot(x="state_name",y="positive",data =covid)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.lineplot(x="state_name",y="positive",data =covid)
plt.xticks(rotation='vertical')
sns.lineplot(x="state_name",y="cured",data =covid)
plt.show()

# %%
from matplotlib import ticker

# %%
#plt.figure(figsize=(18,18))
covid.plot(kind='bar')

# %%
deaths = covid["death"].sum()
deaths
# Out:
# 110586

# %%
covid["positive"].sum()
# Out:
# 7239389

# %%
covid1=covid.iloc[:,1:3]

# %%
covid1.head()
# Out:
#    active  positive
# 0     199      4036
# 1   42855    763573
# 2    2960     12561
# 3   28897    196786
# 4   10835    198855

# %%
covid1.plot(kind="barh",figsize=(10,10))
plt.show()
